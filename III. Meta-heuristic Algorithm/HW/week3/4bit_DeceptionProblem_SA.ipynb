# %%
# 處理 array
import numpy as np

# 產生隨機 list，用於隨機產生出一組合法解
import random

# 計算平方、絕對值
import math

# data visualisation and manipulation
# 畫收斂圖
import matplotlib.pyplot as plt

# %%
# STEP 1 Initialization:
# 隨機產生出一組合法解 (至多2的15次方種可能解)

def ramdomSolution():
    # 隨機生成 4 bits 0/1 長度
    string_status = [ random.randint(0,1) for _ in range(n)]
    
    #計算初始解適應值
    current_value = Evaluation(string_status)
            
    return string_status, current_value

# %%
# STEP 2 Transition: 產生一個或多個解 隨機 / 左右 移動
# 找鄰近解
# 採隨機移動 (1)將任一位置 0換成 1 1換成 0 
# 採左右移動 (2)將任兩不同值位置 0、1對調  

def getNeighbor(solution):
    
    neightbor_sol = solution.copy()

    """
    # 採左右移動 (1)使解往左走+1或往右走-1 0001->0010 or 0001->0000
    # 採左移 +1
    # 二進位左移 +1 ，超過歸 bit數 0 (ex: [1, 1, 1, 1] +1 -> [0, 0, 0, 0])
    for i in range(n-1,-1,-1):
        if(neightbor_sol[i] == 0):
            neightbor_sol[i] = 1
            break
        else:
            neightbor_sol[i] = 0
    
    """
    # 採隨機移動 (2)隨機找其中一個bit 0換成 1 1換成 0 
        
    i = random.randint(0,n-1)

    # 多一個 1 
    if(neightbor_sol[i] == 0):
        neightbor_sol[i]=1
    # 少一個 1 
    else: 
        neightbor_sol[i] = 0
 
    neighbor_value = Evaluation(neightbor_sol)
    
    return neightbor_sol, neighbor_value
    
# n=4
# getNeighbor([0,1,1,0])

# %%
# STEP 3 Evaluation: 評估一個或多個解 適應值(Fitness value)大小
# 公式為|(二進位轉十進位)-2^(n-2)| ex:1111帶入公式：|15-2^(4-2)|=11

def Evaluation(solution):

    # 陣列轉字串
    str_sol = "".join([str(_) for _ in solution])

    # str轉int 2進位 轉 10進位
    dec_sol = int(str_sol,2)

    # 適應值 公式 |(二進位轉十進位)-2^(n-2)|
    sol_val = abs( dec_sol - math.pow(2,n-2))
    
    return sol_val

# %%
# STEP 4 Determination: 將 STEP 3 評估出的適應值與先前的進行比較
# 退火環節:
# 使用退火溫度(T)和適應值的差值(Δf)計算出允許機率，接著隨機一個0–1的浮點數(r)，若該隨機值(r)≤允許機率則進行更新

def simulatedAnnealing(current_sol, currrent_value):
    
    avg_val = 0
    total_val = 0
    
    for i in range(run):
        neightbor_sol, neighbor_value = getNeighbor(current_sol)
        #print("\n鄰近解: " + str(neightbor_sol))
        #print("鄰近解獲利: " + str(neighbor_value))

        # 鄰近解若優於或等於先前解則更新
        if(currrent_value <= neighbor_value):

            current_sol = neightbor_sol
            currrent_value = neighbor_value

        # 若差於先前解則進行退火環節
        else:

            # 隨機值(r:0~1的浮點數)
            r = random.random()

            # Δf < 0 ，故找最大值為: 鄰近解 - 先前解
            Δf = (neighbor_value - currrent_value)
            accept_p = np.exp( (neighbor_value - currrent_value) / current_temperature )

            #print("r,accept_p,Δf")
            #print(r,accept_p,Δf)
            #print(min(r,accept_p))

            # 隨機值(r:0~1的浮點數) ≤ 允許機率則進行更新
            # e的指數若是一個很小的負值，計算後的值會較接近1，差值較小的情形能有比較大的機率接受更新
            if(r <= accept_p):
                current_sol = neightbor_sol
                currrent_value = neighbor_value
                #print("接受差值")
        
        total_val += currrent_value
    
    #跑51次平均值
    avg_val = total_val / run
    
    return current_sol, currrent_value, avg_val

# %%
# main code

# STEP 0 Setting: 初始參數:

global n,iteration,run; 

# 4 bits
n = 4 
print("bit 數:",n)

# 迭代次數(Iteration)
iteration = 1000

# 平均迭代1次 run 次數
run = 51

# 初始溫度(T) 退火溫度
current_temperature = 14.0

# 退火係數(Rₜ)
Rₜ = 0.95

# STEP 1 Initial:
# 隨機產生出一組合法解 

#測試最差初始解
# current_sol = np.zeros(n)
# currrent_value = 0

current_sol, currrent_value = ramdomSolution()
print("\n初始解: " + str(current_sol))
print("初始解值: " + str(currrent_value))

value_history = []

# 迭代 1000 次停止
for k in range(iteration):
    
    current_sol, currrent_value, avg_val = simulatedAnnealing(current_sol, currrent_value)
  
    # 每次迭代的最後皆需進行降溫動作(T = T * Rₜ)，會將溫度T乘上一個小於1的數值(Rₜ)，Rₜ的數值大小取決於想要的收斂速度
    # T (T = T * Rₜ) 會隨著迭代的進行而越來越小，從初始值1開始，隨著迭代不斷下降
    # Δf( Δf = 鄰近解 - 先前解) 除上一個小於1的值(T)，會將 Δf 的值放大，變成一個更大的負數
    # e的指數若是一個很大的負值，計算後的值會很接近 0，成功更新的機率變得更低
    current_temperature = current_temperature * Rₜ
    
    # 紀錄每次迭代的平均值
    value_history.append(avg_val)
    
    print("\n第" + str(k+1) + "輪: ")
    print("解: " + str(current_sol))
    print("解值: " + str(currrent_value))
    print("平均解值: " + str(avg_val))

print("\n最佳解: " + str(current_sol))
print("最佳值: " + str(currrent_value))
# Out:
# bit 數: 4
#
# 初始解: [0, 1, 1, 0]
# 初始解值: 2.0
#
# 第1輪:
# 解: [1, 0, 0, 0]
# 解值: 4.0
# 平均解值: 5.784313725490196
#
# 第2輪:
# 解: [1, 1, 0, 1]
# 解值: 9.0
# 平均解值: 5.901960784313726
#
# 第3輪:
# 解: [1, 0, 1, 1]
# 解值: 7.0
# 平均解值: 5.333333333333333
#
# 第4輪:
# 解: [0, 1, 1, 0]
# 解值: 2.0
# 平均解值: 5.980392156862745
#
# 第5輪:
# 解: [1, 1, 1, 0]
# 解值: 10.0
# 平均解值: 4.901960784313726
#
# 第6輪:
# 解: [1, 1, 0, 0]
# 解值: 8.0
# 平均解值: 4.294117647058823
#
# 第7輪:
# 解: [0, 1, 0, 0]
# 解值: 0.0
# 平均解值: 7.137254901960785
#
# 第8輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 5.823529411764706
#
# 第9輪:
# 解: [1, 1, 0, 1]
# 解值: 9.0
# 平均解值: 6.568627450980392
#
# 第10輪:
# 解: [0, 0, 1, 1]
# 解值: 1.0
# 平均解值: 4.8431372549019605
#
# 第11輪:
# 解: [1, 0, 0, 1]
# 解值: 5.0
# 平均解值: 6.392156862745098
#
# 第12輪:
# 解: [1, 1, 1, 0]
# 解值: 10.0
# 平均解值: 6.862745098039215
#
# 第13輪:
# 解: [1, 0, 0, 0]
# 解值: 4.0
# 平均解值: 5.431372549019608
#
# 第14輪:
# 解: [0, 0, 0, 1]
# 解值: 3.0
# 平均解值: 6.823529411764706
#
# 第15輪:
# 解: [0, 1, 0, 1]
# 解值: 1.0
# 平均解值: 7.0588235294117645
#
# 第16輪:
# 解: [0, 0, 1, 1]
# 解值: 1.0
# 平均解值: 7.0
#
# 第17輪:
# 解: [1, 0, 0, 0]
# 解值: 4.0
# 平均解值: 6.529411764705882
#
# 第18輪:
# 解: [1, 1, 0, 0]
# 解值: 8.0
# 平均解值: 8.509803921568627
#
# 第19輪:
# 解: [0, 0, 0, 1]
# 解值: 3.0
# 平均解值: 6.078431372549019
#
# 第20輪:
# 解: [1, 1, 0, 0]
# 解值: 8.0
# 平均解值: 7.862745098039215
#
# 第21輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 8.411764705882353
#
# 第22輪:
# 解: [1, 0, 1, 0]
# 解值: 6.0
# 平均解值: 6.803921568627451
#
# 第23輪:
# 解: [1, 1, 0, 0]
# 解值: 8.0
# 平均解值: 7.490196078431373
#
# 第24輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 6.9411764705882355
#
# 第25輪:
# 解: [1, 1, 1, 0]
# 解值: 10.0
# 平均解值: 8.313725490196079
#
# 第26輪:
# 解: [1, 1, 1, 0]
# 解值: 10.0
# 平均解值: 8.568627450980392
#
# 第27輪:
# 解: [1, 0, 0, 1]
# 解值: 5.0
# 平均解值: 5.764705882352941
#
# 第28輪:
# 解: [1, 1, 0, 1]
# 解值: 9.0
# 平均解值: 8.352941176470589
#
# 第29輪:
# 解: [1, 1, 1, 0]
# 解值: 10.0
# 平均解值: 8.745098039215685
#
# 第30輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.019607843137255
#
# 第31輪:
# 解: [1, 1, 0, 0]
# 解值: 8.0
# 平均解值: 9.431372549019608
#
# 第32輪:
# 解: [1, 1, 0, 0]
# 解值: 8.0
# 平均解值: 8.176470588235293
#
# 第33輪:
# 解: [1, 1, 0, 1]
# 解值: 9.0
# 平均解值: 9.450980392156863
#
# 第34輪:
# 解: [1, 1, 0, 0]
# 解值: 8.0
# 平均解值: 9.96078431372549
#
# 第35輪:
# 解: [1, 1, 1, 0]
# 解值: 10.0
# 平均解值: 9.627450980392156
#
# 第36輪:
# 解: [1, 1, 1, 0]
# 解值: 10.0
# 平均解值: 8.941176470588236
#
# 第37輪:
# 解: [1, 0, 0, 1]
# 解值: 5.0
# 平均解值: 9.137254901960784
#
# 第38輪:
# 解: [1, 1, 0, 0]
# 解值: 8.0
# 平均解值: 7.7254901960784315
#
# 第39輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 9.411764705882353
#
# 第40輪:
# 解: [1, 1, 1, 0]
# 解值: 10.0
# 平均解值: 9.901960784313726
#
# 第41輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 7.666666666666667
#
# 第42輪:
# 解: [1, 0, 1, 1]
# 解值: 7.0
# 平均解值: 9.098039215686274
#
# 第43輪:
# 解: [1, 1, 0, 0]
# 解值: 8.0
# 平均解值: 9.92156862745098
#
# 第44輪:
# 解: [1, 1, 1, 0]
# 解值: 10.0
# 平均解值: 10.196078431372548
#
# 第45輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.294117647058824
#
# 第46輪:
# 解: [1, 1, 1, 0]
# 解值: 10.0
# 平均解值: 9.96078431372549
#
# 第47輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 9.92156862745098
#
# 第48輪:
# 解: [1, 1, 1, 0]
# 解值: 10.0
# 平均解值: 10.470588235294118
#
# 第49輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.411764705882353
#
# 第50輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.72549019607843
#
# 第51輪:
# 解: [1, 1, 1, 0]
# 解值: 10.0
# 平均解值: 10.431372549019608
#
# 第52輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.803921568627452
#
# 第53輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.607843137254902
#
# 第54輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.980392156862745
#
# 第55輪:
# 解: [1, 1, 0, 1]
# 解值: 9.0
# 平均解值: 10.823529411764707
#
# 第56輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.431372549019608
#
# 第57輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.843137254901961
#
# 第58輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.882352941176471
#
# 第59輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.666666666666666
#
# 第60輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.549019607843137
#
# 第61輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.686274509803921
#
# 第62輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.823529411764707
#
# 第63輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.92156862745098
#
# 第64輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.72549019607843
#
# 第65輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.96078431372549
#
# 第66輪:
# 解: [1, 1, 1, 0]
# 解值: 10.0
# 平均解值: 10.941176470588236
#
# 第67輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.764705882352942
#
# 第68輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.92156862745098
#
# 第69輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.862745098039216
#
# 第70輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第71輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第72輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第73輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.941176470588236
#
# 第74輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第75輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.92156862745098
#
# 第76輪:
# 解: [1, 1, 1, 0]
# 解值: 10.0
# 平均解值: 10.96078431372549
#
# 第77輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.941176470588236
#
# 第78輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第79輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第80輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第81輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第82輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第83輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第84輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第85輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 10.96078431372549
#
# 第86輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第87輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第88輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第89輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第90輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第91輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第92輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第93輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第94輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第95輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第96輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第97輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第98輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第99輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第100輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第101輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第102輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第103輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第104輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第105輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第106輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第107輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第108輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第109輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第110輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第111輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第112輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第113輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第114輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第115輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第116輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第117輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第118輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第119輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第120輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第121輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第122輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第123輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第124輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第125輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第126輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第127輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第128輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第129輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第130輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第131輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第132輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第133輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第134輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第135輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第136輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第137輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第138輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第139輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第140輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第141輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第142輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第143輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第144輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第145輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第146輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第147輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第148輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第149輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第150輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第151輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第152輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第153輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第154輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第155輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第156輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第157輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第158輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第159輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第160輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第161輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第162輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第163輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第164輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第165輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第166輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第167輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第168輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第169輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第170輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第171輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第172輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第173輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第174輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第175輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第176輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第177輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第178輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第179輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第180輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第181輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第182輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第183輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第184輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第185輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第186輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第187輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第188輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第189輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第190輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第191輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第192輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第193輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第194輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第195輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第196輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第197輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第198輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第199輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第200輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第201輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第202輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第203輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第204輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第205輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第206輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第207輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第208輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第209輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第210輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第211輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第212輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第213輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第214輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第215輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第216輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第217輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第218輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第219輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第220輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第221輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第222輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第223輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第224輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第225輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第226輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第227輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第228輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第229輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第230輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第231輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第232輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第233輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第234輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第235輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第236輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第237輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第238輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第239輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第240輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第241輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第242輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第243輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第244輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第245輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第246輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第247輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第248輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第249輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第250輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第251輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第252輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第253輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第254輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第255輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第256輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第257輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第258輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第259輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第260輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第261輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第262輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第263輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第264輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第265輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第266輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第267輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第268輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第269輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第270輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第271輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第272輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第273輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第274輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第275輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第276輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第277輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第278輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第279輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第280輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第281輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第282輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第283輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第284輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第285輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第286輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第287輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第288輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第289輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第290輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第291輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第292輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第293輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第294輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第295輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第296輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第297輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第298輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第299輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第300輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第301輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第302輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第303輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第304輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第305輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第306輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第307輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第308輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第309輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第310輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第311輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第312輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第313輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第314輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第315輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第316輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第317輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第318輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第319輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第320輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第321輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第322輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第323輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第324輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第325輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第326輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第327輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第328輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第329輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第330輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第331輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第332輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第333輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第334輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第335輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第336輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第337輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第338輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第339輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第340輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第341輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第342輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第343輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第344輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第345輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第346輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第347輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第348輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第349輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第350輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第351輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第352輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第353輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第354輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第355輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第356輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第357輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第358輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第359輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第360輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第361輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第362輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第363輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第364輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第365輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第366輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第367輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第368輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第369輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第370輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第371輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第372輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第373輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第374輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第375輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第376輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第377輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第378輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第379輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第380輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第381輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第382輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第383輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第384輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第385輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第386輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第387輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第388輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第389輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第390輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第391輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第392輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第393輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第394輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第395輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第396輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第397輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第398輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第399輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第400輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第401輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第402輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第403輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第404輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第405輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第406輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第407輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第408輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第409輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第410輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第411輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第412輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第413輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第414輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第415輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第416輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第417輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第418輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第419輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第420輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第421輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第422輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第423輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第424輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第425輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第426輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第427輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第428輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第429輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第430輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第431輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第432輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第433輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第434輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第435輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第436輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第437輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第438輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第439輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第440輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第441輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第442輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第443輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第444輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第445輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第446輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第447輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第448輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第449輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第450輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第451輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第452輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第453輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第454輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第455輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第456輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第457輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第458輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第459輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第460輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第461輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第462輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第463輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第464輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第465輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第466輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第467輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第468輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第469輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第470輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第471輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第472輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第473輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第474輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第475輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第476輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第477輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第478輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第479輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第480輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第481輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第482輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第483輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第484輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第485輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第486輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第487輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
# 第488輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第489輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第490輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第491輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第492輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第493輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第494輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第495輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第496輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第497輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第498輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第499輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第500輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第501輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第502輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第503輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第504輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第505輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第506輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第507輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第508輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第509輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第510輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第511輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第512輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第513輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第514輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第515輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第516輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第517輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第518輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第519輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第520輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第521輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第522輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第523輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第524輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第525輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第526輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第527輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第528輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第529輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第530輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第531輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第532輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第533輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第534輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第535輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第536輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第537輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第538輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第539輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第540輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第541輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第542輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第543輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第544輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第545輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第546輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第547輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第548輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第549輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第550輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第551輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第552輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第553輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第554輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第555輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第556輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第557輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第558輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第559輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第560輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第561輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第562輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第563輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第564輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第565輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第566輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第567輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第568輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第569輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第570輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第571輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第572輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第573輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第574輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第575輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第576輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第577輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第578輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第579輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第580輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第581輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第582輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第583輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第584輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第585輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第586輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第587輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第588輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第589輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第590輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第591輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第592輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第593輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第594輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第595輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第596輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第597輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第598輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第599輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第600輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第601輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第602輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第603輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第604輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第605輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第606輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第607輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第608輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第609輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第610輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第611輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第612輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第613輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第614輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第615輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第616輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第617輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第618輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第619輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第620輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第621輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第622輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第623輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第624輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第625輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第626輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第627輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第628輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第629輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第630輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第631輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第632輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第633輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第634輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第635輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第636輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第637輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第638輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第639輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第640輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第641輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第642輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第643輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第644輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第645輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第646輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第647輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第648輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第649輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第650輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第651輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第652輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第653輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第654輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第655輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第656輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第657輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第658輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第659輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第660輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第661輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第662輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第663輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第664輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第665輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第666輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第667輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第668輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第669輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第670輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第671輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第672輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第673輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第674輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第675輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第676輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第677輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第678輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第679輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第680輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第681輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第682輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第683輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第684輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第685輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第686輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第687輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第688輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第689輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第690輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第691輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第692輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第693輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第694輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第695輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第696輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第697輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第698輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第699輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第700輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第701輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第702輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第703輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第704輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第705輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第706輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第707輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第708輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第709輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第710輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第711輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第712輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第713輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第714輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第715輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第716輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第717輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第718輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第719輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第720輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第721輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第722輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第723輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第724輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第725輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第726輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第727輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第728輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第729輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第730輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第731輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第732輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第733輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第734輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第735輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第736輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第737輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第738輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第739輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第740輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第741輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第742輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第743輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第744輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第745輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第746輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第747輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第748輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第749輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第750輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第751輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第752輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第753輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第754輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第755輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第756輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第757輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第758輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第759輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第760輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第761輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第762輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第763輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第764輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第765輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第766輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第767輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第768輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第769輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第770輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第771輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第772輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第773輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第774輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第775輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第776輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第777輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第778輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第779輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第780輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第781輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第782輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第783輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第784輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第785輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第786輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第787輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第788輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第789輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第790輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第791輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第792輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第793輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第794輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第795輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第796輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第797輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第798輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第799輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第800輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第801輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第802輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第803輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第804輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第805輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第806輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第807輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第808輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第809輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第810輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第811輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第812輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第813輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第814輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第815輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第816輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第817輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第818輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第819輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第820輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第821輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第822輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第823輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第824輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第825輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第826輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第827輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第828輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第829輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第830輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第831輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第832輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第833輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第834輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第835輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第836輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第837輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第838輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第839輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第840輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第841輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第842輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第843輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第844輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第845輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第846輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第847輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第848輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第849輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第850輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第851輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第852輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第853輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第854輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第855輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第856輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第857輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第858輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第859輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第860輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第861輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第862輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第863輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第864輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第865輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第866輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第867輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第868輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第869輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第870輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第871輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第872輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第873輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第874輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第875輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第876輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第877輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第878輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第879輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第880輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第881輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第882輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第883輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第884輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第885輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第886輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第887輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第888輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第889輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第890輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第891輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第892輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第893輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第894輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第895輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第896輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第897輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第898輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第899輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第900輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第901輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第902輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第903輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第904輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第905輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第906輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第907輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第908輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第909輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第910輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第911輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第912輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第913輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
# 第914輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第915輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第916輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第917輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第918輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第919輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第920輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第921輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第922輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第923輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第924輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第925輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第926輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第927輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第928輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第929輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第930輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第931輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第932輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第933輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第934輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第935輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第936輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第937輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第938輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第939輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第940輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第941輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第942輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第943輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第944輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第945輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第946輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第947輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第948輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第949輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第950輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第951輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第952輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第953輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第954輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第955輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第956輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第957輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第958輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第959輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第960輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第961輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第962輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第963輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第964輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第965輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第966輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第967輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第968輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第969輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第970輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第971輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第972輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第973輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第974輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第975輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第976輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第977輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第978輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第979輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第980輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第981輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第982輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第983輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第984輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第985輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第986輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第987輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第988輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第989輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第990輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第991輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第992輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第993輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第994輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第995輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第996輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第997輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第998輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第999輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 第1000輪:
# 解: [1, 1, 1, 1]
# 解值: 11.0
# 平均解值: 11.0
#
# 最佳解: [1, 1, 1, 1]
# 最佳值: 11.0

# %%
def plotIteration(value_history, iteration):
    
    iterationTime = iteration

    plt.title('circle of average convergence')
    plt.plot(range(1, iterationTime + 1), value_history, label='Objective Value')
    plt.xlabel('Iteration')
    plt.ylabel('Objective Value')
    plt.legend()
    plt.grid()
    plt.show()
    
# 畫平均收斂圖
plotIteration(value_history, iteration)
print("最佳解: ", currrent_value)
print("平均最佳解: ", max(value_history))
# Out:
# 最佳解:  11.0
# 平均最佳解:  11.0
